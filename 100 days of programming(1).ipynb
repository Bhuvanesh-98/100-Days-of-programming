# %% [markdown]
# # DAY 2 CHALLENGE (PATTERN PROGRAM TO PRINT MY NAME WITH PREDEFINED INPUTS)

# %%
for i in range(0,7):
    for j in range(0,5):
        if(j==0) or (j==4 and(i!=0 and i!=3 and i!=6)) or ((i==0 or i==3  or i==6)and j!=4):
            print("*",end="")
        else:
            print(" ",end="")
    print()
print()  
for i in range(0,7):
    for j in range(0,5):
        if(j==0 or j==4)or(i==3and(j>0 and j<4)):
            print("*",end="")
        else:
            print(" ",end="")
    print()
print()    
for i in range(0,7):
    for j in range(0,5):
        if((j==0 or j==4) and i!=6) or(i==6 and (j>0 and j<4)):
            print("*",end="")
        else:
            print(" ",end="")
    print()
print()
for i in range(0,4):
    for j in range(0,7):
        if(i==0 and(j==0 or j==6)) or (i==1 and(j==1 or j==5))or (i==2 and(j==2 or j==4)) or (i==3 and j==3):
                                                                                            
            print("*",end="")
                                                                                                
        else:
            print(" ",end="")
    print()
print()
for i in range(7):
    for j in range(5):
        if ((j==0 or j==4) and i!=0) or ((i==0 or i==3) and (j>0 and j<4)):
            print("*",end="")
        else:
            print(end=" ")
    print()
print()
for i in range(7):
    for j in range(5):
        if ((j==0 or j==4) and i!=0) or ((i==0 or i==3) and (j>0 and j<4)):
            print("*",end="")
        else:
            print(end=" ")
    print()
print()
for i in range(0,7):
    for j in range(0,5):
        if(j==0) or (i==0 and j>0) or (i==3 and j>0) or (i==6 and j>0) :
            print("*",end="")
        else:
            print(" ",end="")
    print()
print()
str="";    
for Row in range(0,7):    
    for Col in range(0,7):     
        if (((Row == 0 or Row == 3 or Row == 6) and Col > 1 and Col < 5) or (Col == 1 and (Row == 1 or Row == 2 or Row == 6)) or (Col == 5 and (Row == 0 or Row == 4 or Row == 5))):  
            str=str+"*"    
        else:      
            str=str+" "    
    str=str+"\n"    
print(str);  
print()
for i in range(0,7):
    for j in range(0,5):
        if(j==0 or j==4)or(i==3and(j>0 and j<4)):
            print("*",end="")
        else:
            print(" ",end="")
    print()
# Out:
# ****
# *   *
# *   *
# ****
# *   *
# *   *
# ****
#
# *   *
# *   *
# *   *
# *****
# *   *
# *   *
# *   *
#
# *   *
# *   *
# *   *
# *   *
# *   *
# *   *
#  ***
#
# *     *
#  *   *
#   * *
#    *
#
#  ***
# *   *
# *   *
# *****
# *   *
# *   *
# *   *
#
#  ***
# *   *
# *   *
# *****
# *   *
# *   *
# *   *
#
# *****
# *
# *
# *****
# *
# *
# *****
#
#   ****
#  *
#  *
#   ***
#      *
#      *
#  ****
#
#
# *   *
# *   *
# *   *
# *****
# *   *
# *   *
# *   *
